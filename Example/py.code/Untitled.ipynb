# %%
import matplotlib.pyplot as plt
from numpy import sin
from numpy import cos
 
x = np.linspace(-2, 2, 10000)
f = lambda x: np.sqrt(cos(x)) * cos(80 * x) + 0.5 * np.sqrt(abs(x))
plt.plot(x, f(x))
#plt.show()
plt.savefig("13.pdf")
# Out:
# /var/folders/kk/2pj93ygs67nbx9_42r_c6_3c0000gn/T/ipykernel_56508/486823670.py:6: RuntimeWarning: invalid value encountered in sqrt
#   f = lambda x: np.sqrt(cos(x)) * cos(80 * x) + 0.5 * np.sqrt(abs(x))
