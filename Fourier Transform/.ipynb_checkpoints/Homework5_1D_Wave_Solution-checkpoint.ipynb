# %%
import numpy as np
from scipy import fft
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 15})
#%config InlineBackend.figure_format='retina'

# %%
N = 121 # number of grid points in x
xlim = [-1, 1] # bound of x
L  = xlim[1] - xlim[0]
xj = np.linspace(*xlim, N + 1)[:-1]
kj = np.hstack([
    np.arange(0,   N/2),     # k > 0 domain
    np.arange(-int(N/2), 0), # k < 0 domain
]) * 2*np.pi/L

dt = 4 / N**2 # stability criterion is a whole different subject...
tmax = 4      # the maximum time to integrate
datadump_freq = int(0.01 / dt) # intermediate data dump frequency
outer_loop_count = int(tmax/dt / datadump_freq)

uj = -1 * np.exp(-200 * xj**2)            # - u(  0, x)
uj_old = -1 * np.exp(-200 * (xj - dt)**2) # - u(-Dt, x)

# time and u data containers
t_data = [dt] * (1 + outer_loop_count)
u_data = [uj] * (1 + outer_loop_count)

for i in range(outer_loop_count):
    t_data[i] *= i * datadump_freq
    u_data[i]  = uj

    for _ in range(datadump_freq):
        Uj = fft.fft(uj)
        Wj = -kj**2 * Uj       # approximation for u_xx
        wj = fft.ifft(Wj).real # remove the imaginary part, which should all be zeros
        uj_old, uj = uj, 2*uj - uj_old + dt**2*wj

t_data[-1] *= i * datadump_freq
u_data[-1]  = uj


#plot
fig, ax = plt.subplots(figsize=(7, 7), ncols=1)

pos = ax.imshow(u_data, interpolation='none', origin='lower', cmap='viridis',
           extent=np.hstack(([xj[0], xj[-1]], [t_data[0], t_data[-1]])),
           aspect='auto')
fig.colorbar(pos, ax=ax, location='right', anchor=(0, 0.3), shrink=0.7,
             label="$u(t, x)$")
ax.set_xlabel("$x$")
ax.set_ylabel("$t$")

plt.savefig("1d_Wave_Solution.pdf")

# %%
N = 121 # number of grid points in x
xlim = [-1, 1] # bound of x
L  = xlim[1] - xlim[0]
xj = np.linspace(*xlim, N + 1)[:-1]
kj = np.hstack([
    np.arange(0,   N/2),     # k > 0 domain
    np.arange(-int(N/2), 0), # k < 0 domain
]) * 2*np.pi/L

dt = 4 / N**2 # stability criterion is a whole different subject...
tmax = 4      # the maximum time to integrate
datadump_freq = int(0.01 / dt) # intermediate data dump frequency
outer_loop_count = int(tmax/dt / datadump_freq)

uj = -1 * np.exp(-200 * (xj + 0.5)**2)            # - u(  0, x)
uj_old = -1 * np.exp(-200 * ((xj + 0.5) - dt)**2) # - u(-Dt, x)

# time and u data containers
t_data_u1 = [dt] * (1 + outer_loop_count)
u_data_u1 = [uj] * (1 + outer_loop_count)

for i in range(outer_loop_count):
    t_data_u1[i] *= i * datadump_freq
    u_data_u1[i]  = uj

    for _ in range(datadump_freq):
        Uj = fft.fft(uj)
        Wj = -kj**2 * Uj       # approximation for u_xx
        wj = fft.ifft(Wj).real # remove the imaginary part, which should all be zeros
        uj_old, uj = uj, 2*uj - uj_old + dt**2*wj

t_data_u1[-1] *= i * datadump_freq
u_data_u1[-1]  = uj


#plot
fig, ax = plt.subplots(figsize=(7, 7), ncols=1)

pos = ax.imshow(u_data_u1, interpolation='none', origin='lower', cmap='viridis',
           extent=np.hstack(([xj[0], xj[-1]], [t_data_u1[0], t_data_u1[-1]])),
           aspect='auto')
fig.colorbar(pos, ax=ax, location='right', anchor=(0, 0.3), shrink=0.7,
             label="$u(t, x)$")
ax.set_xlabel("$x$")
ax.set_ylabel("$t$")

plt.savefig("1D_wave_solution2_u1.pdf")

# %%
N = 121 # number of grid points in x
xlim = [-1, 1] # bound of x
L  = xlim[1] - xlim[0]
xj = np.linspace(*xlim, N + 1)[:-1]
kj = np.hstack([
    np.arange(0,   N/2),     # k > 0 domain
    np.arange(-int(N/2), 0), # k < 0 domain
]) * 2*np.pi/L

dt = 4 / N**2 # stability criterion is a whole different subject...
tmax = 4      # the maximum time to integrate
datadump_freq = int(0.01 / dt) # intermediate data dump frequency
outer_loop_count = int(tmax/dt / datadump_freq)

uj = np.exp(-200 * (xj - 0.5)**2)            # - u(  0, x)
uj_old = np.exp(-200 * ((xj - 0.5) - dt)**2) # - u(-Dt, x)

# time and u data containers
t_data = [dt] * (1 + outer_loop_count)
u_data = [uj] * (1 + outer_loop_count)

for i in range(outer_loop_count):
    t_data[i] *= i * datadump_freq
    u_data[i]  = uj

    for _ in range(datadump_freq):
        Uj = fft.fft(uj)
        Wj = -kj**2 * Uj       # approximation for u_xx
        wj = fft.ifft(Wj).real # remove the imaginary part, which should all be zeros
        uj_old, uj = uj, 2*uj - uj_old + dt**2*wj

t_data[-1] *= i * datadump_freq
u_data[-1]  = uj


#plot
fig, ax = plt.subplots(figsize=(7, 7), ncols=1)

pos = ax.imshow(u_data, interpolation='none', origin='lower', cmap='viridis',
           extent=np.hstack(([xj[0], xj[-1]], [t_data[0], t_data[-1]])),
           aspect='auto')

fig.colorbar(pos, ax=ax, location='right', anchor=(0, 0.3), shrink=0.7,
             label="$u(t, x)$")
ax.set_xlabel("$x$")
ax.set_ylabel("$t$")

plt.savefig("1d_Wave_Solution2_u2.pdf")

# %%
N = 121 # number of grid points in x
xlim = [-1, 1] # bound of x
L  = xlim[1] - xlim[0]
xj = np.linspace(*xlim, N + 1)[:-1]
kj = np.hstack([
    np.arange(0,   N/2),     # k > 0 domain
    np.arange(-int(N/2), 0), # k < 0 domain
]) * 2*np.pi/L

dt = 4 / N**2 # stability criterion is a whole different subject...
tmax = 4      # the maximum time to integrate
datadump_freq = int(0.01 / dt) # intermediate data dump frequency
outer_loop_count = int(tmax/dt / datadump_freq)

uj = np.exp(-200 * (xj - 0.5)**2)            # - u(  0, x)
uj_old = np.exp(-200 * ((xj - 0.5) - dt)**2) # - u(-Dt, x)

# time and u data containers
t_data = [dt] * (1 + outer_loop_count)
u_data = [uj] * (1 + outer_loop_count)

for i in range(outer_loop_count):
    t_data[i] *= i * datadump_freq
    u_data[i]  = uj

    for _ in range(datadump_freq):
        Uj = fft.fft(uj)
        Wj = -kj**2 * Uj       # approximation for u_xx
        wj = fft.ifft(Wj).real # remove the imaginary part, which should all be zeros
        uj_old, uj = uj, 2*uj - uj_old + dt**2*wj

t_data[-1] *= i * datadump_freq
u_data[-1]  = uj


#plot
fig, ax = plt.subplots(figsize=(7, 7), ncols=1)


pos_1 = ax.imshow(u_data_u1, interpolation='none', origin='lower', cmap='viridis',
           extent=np.hstack(([xj[0], xj[-1]], [t_data_u1[0], t_data_u1[-1]])),
           aspect='auto')
pos_2 = ax.imshow(u_data, interpolation='none', origin='lower', cmap='viridis',
           extent=np.hstack(([xj[0], xj[-1]], [t_data[0], t_data[-1]])),
           aspect='auto')

fig.colorbar(pos_1, ax=ax, location='right', anchor=(0, 0.3), shrink=0.7,
             label="$u(t, x)$")
fig.colorbar(pos_2, ax=ax, location='right', anchor=(0, 0.3), shrink=0.7,
             label="$u(t, x)$")

ax.set_xlabel("$x$")
ax.set_ylabel("$t$")

plt.savefig("1d_Wave_Solution2_u1 + u2.pdf")

# %%
import numpy as np
import cv2


def addImage(imgfile, imgfile2):
    img1 = cv2.imread(imgfile)
    img2 = cv2.imread(imgfile2)

    img1 = cv2.resize(img1, (479, 557))

    print(img1.shape)
    print(img2.shape)

    cv2.imshow('img1', img1)
    cv2.imshow('img2', img2)

    add_img1 = img1 + img2
    add_img2 = cv2.add(img1, img2)

    cv2.imshow("img1 + img2", add_img1)
    cv2.imshow("cv2.add", add_img2)

    cv2.waitKey(0)
    cv2.destroyAllWindows()


addImage("/Users/kang0/Desktop/Numerical-Analysis/Fourier Transform/1D_wave_solution2_u1", "/Users/kang0/Desktop/Numerical-Analysis/Fourier Transform/1D_wave_solution2_u2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/kk/2pj93ygs67nbx9_42r_c6_3c0000gn/T/ipykernel_38781/3742381374.py in <module>
#       1 import numpy as np
# ----> 2 import cv2
#       3
#       4
#       5 def addImage(imgfile, imgfile2):
#
# ModuleNotFoundError: No module named 'cv2'
