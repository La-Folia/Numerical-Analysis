# %%
import numpy as np
import numpy.linalg as la
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 15})
#%config InlineBackend.figure_format='retina'

# %%
def poly_fit(xs, ys):
    """Fit a polynominal of degree n that fits the all data points given.
    
    It returns coefficients, a_n, a_n-1, a_n-2, ..., a_1, a_0, in the polynomial
    
        p(x) = a_n*x^n + a_n-1*x^n-1 + a_n-2*x^n-2 + ... + a_1*x + a_0
    """
    assert len(xs) == len(ys)
    
    i = np.flip(range(len(xs))) # integer exponents are sorted in descending order
                                # so that the first element is the coefficent
                                # of the highest order term
    b = ys
    A = [x ** i for x in xs]
    #print(i)
    #print('-'*40)
    #print(b)
    #print('-'*40)
    #print(A)
    #print('-'*40)
    #print(xs)
    #print('-'*40)

    
    return la.solve(A, b)

def poly_val(aj, x):
    """Evaluate the polynomial
    
        p(x) = a_n*x^n + a_n-1*x^n-1 + a_n-2*x^n-2 + ... + a_1*x + a_0
        
    at x given the coefficients, a_n, a_n-1, a_n-2, ..., a_1, a_0.
    """
    assert len(aj) > 1
    
    y = aj[0]
    #print(y)
    #print('-'*40)    
    for a in aj[1:]:
        y = y*x + a
    #print(aj)
    #print('-'*40)  
    return y

# %%
x1, y1 = -1, 0 # first point
x2, y2 =  1, 3 # second point

# 1-degree polynomial (i.e., line) fitting
coefs = poly_fit([x1, x2], [y1, y2])

# define the grid points to display the fit polynomial
x = np.linspace(-3, 3, 100)
p = poly_val(coefs, x)

plt.figure()
plt.plot(x, p, "-b", lw=1, label="$y = {0}x + {1}$".format(*coefs))
plt.plot([x1, x2], [y1, y2], "ok")
plt.legend()
plt.grid()
plt.show()
# Out:
# 1.5
# ----------------------------------------
# [1.5 1.5]
# ----------------------------------------

# %%
xs = [1, 2]
i = np.array([1,5])
a = [x ** i for x in xs]
print(a)
# Out:
# [array([1, 1]), array([ 2, 32])]

# %%
# exact coefficients
coefs_exact = [
     429/16,  # x^7
          0,  # x^6
    -693/16,  # x^5
          0,  # x^4
     315/16,  # x^3
          0,  # x^2
     -35/16,  # x^1
          0,  # x^0
]

def legendre_7th(x):
    return poly_val(coefs_exact, x)

# random points
N    = 7
xlim = -1, 1
xs   = np.random.uniform(*xlim, N + 1) # we need N + 1 points!
ys   = legendre_7th(xs)

# poly fit
coefs_fit  = poly_fit(xs, ys)

coefs_fit - coefs_exact
# Out:
# array([ 4.01456646e-13,  2.86242800e-13, -4.40536496e-13, -3.40004023e-13,
#         7.10542736e-14,  8.27872793e-14,  1.11022302e-14, -1.47078049e-16])

# %%
from scipy.special import eval_legendre

N = 7

# draw
xs = np.linspace(-1, 1, 200)
ys = eval_legendre(N, xs)
ps = poly_val(coefs_fit, xs)

print("rms error = {}".format(abs(ys - ps)))

plt.figure()

plt.plot(xs, ys, "-b", xs, ps, "--r")
plt.xlabel("$x$")
plt.legend([f"$P_{N}(x)$", "p(x)"])
plt.grid()

plt.show()
# Out:
# rms error = [1.42108547e-14 1.01030295e-14 9.10382880e-15 7.21644966e-15
#  3.38618023e-15 2.07993345e-15 1.04083409e-15 1.41553436e-15
#  2.22044605e-16 3.49720253e-15 1.94289029e-15 3.55271368e-15
#  1.11022302e-15 3.44169138e-15 3.10862447e-15 4.10782519e-15
#  4.88498131e-15 3.16413562e-15 3.99680289e-15 2.77555756e-15
#  2.80331314e-15 3.16413562e-15 1.19348975e-15 3.09474668e-15
#  1.99840144e-15 2.73739365e-15 2.32279473e-15 2.29677388e-15
#  9.71445147e-17 1.74860126e-15 1.24900090e-15 9.43689571e-16
#  9.43689571e-16 8.32667268e-16 3.33066907e-16 1.11022302e-16
#  4.44089210e-16 1.66533454e-16 4.99600361e-16 1.11022302e-16
#  4.99600361e-16 0.00000000e+00 6.10622664e-16 5.55111512e-17
#  5.55111512e-16 7.77156117e-16 5.55111512e-17 3.33066907e-16
#  5.55111512e-17 4.44089210e-16 2.77555756e-17 5.55111512e-17
#  5.55111512e-17 2.49800181e-16 1.66533454e-16 1.94289029e-16
#  3.88578059e-16 1.87350135e-16 6.24500451e-16 3.20056481e-16
#  6.76542156e-16 5.13478149e-16 3.46944695e-16 6.66133815e-16
#  2.22044605e-16 5.82867088e-16 6.93889390e-16 5.55111512e-16
#  6.10622664e-16 4.16333634e-16 6.38378239e-16 4.44089210e-16
#  2.77555756e-16 3.88578059e-16 3.33066907e-16 2.22044605e-16
#  1.66533454e-16 0.00000000e+00 0.00000000e+00 1.11022302e-16
#  1.66533454e-16 1.11022302e-16 2.22044605e-16 2.22044605e-16
#  2.77555756e-16 6.10622664e-16 3.60822483e-16 6.10622664e-16
#  5.27355937e-16 3.88578059e-16 8.60422844e-16 6.66133815e-16
#  6.10622664e-16 6.93889390e-16 2.63677968e-16 8.18789481e-16
#  5.55111512e-16 4.92661467e-16 3.81639165e-16 5.37764278e-17
#  1.07552856e-16 9.02056208e-17 8.32667268e-17 3.33066907e-16
#  4.71844785e-16 6.24500451e-16 9.43689571e-16 1.11022302e-15
#  1.33226763e-15 1.63757896e-15 1.91513472e-15 2.22044605e-15
#  2.58126853e-15 2.85882429e-15 3.21964677e-15 3.55271368e-15
#  3.88578059e-15 4.21884749e-15 4.71844785e-15 5.16253706e-15
#  5.49560397e-15 5.93969318e-15 6.16173779e-15 6.71684930e-15
#  7.10542736e-15 7.32747196e-15 7.66053887e-15 8.27116153e-15
#  8.65973959e-15 8.96505092e-15 9.21485110e-15 9.46465128e-15
#  9.68669589e-15 1.00475184e-14 1.02973186e-14 1.04499742e-14
#  1.06026299e-14 1.08107967e-14 1.07622244e-14 1.07171216e-14
#  1.06776567e-14 1.06893661e-14 1.02765019e-14 1.00891517e-14
#  9.99200722e-15 9.57567359e-15 9.10382880e-15 8.90953977e-15
#  8.16013923e-15 7.71605002e-15 6.74460487e-15 6.05071548e-15
#  5.55111512e-15 4.60742555e-15 3.83026943e-15 2.77555756e-15
#  1.72084569e-15 3.88578059e-16 9.99200722e-16 1.83186799e-15
#  3.05311332e-15 4.55191440e-15 5.93969318e-15 6.93889390e-15
#  9.04831765e-15 9.99200722e-15 1.12410081e-14 1.31006317e-14
#  1.54598556e-14 1.67088565e-14 1.74721349e-14 1.86378690e-14
#  2.05668815e-14 2.10387263e-14 2.28150832e-14 2.37587727e-14
#  2.43000065e-14 2.59237076e-14 2.58404409e-14 2.57571742e-14
#  2.66453526e-14 2.57016630e-14 2.60347299e-14 2.52575738e-14
#  2.46469511e-14 2.33701947e-14 2.07611706e-14 1.84852134e-14
#  1.52100554e-14 1.01585407e-14 5.49560397e-15 7.77156117e-16
#  4.52415883e-15 1.05887521e-14 2.27075303e-14 2.72004641e-14
#  3.55271368e-14 4.74065232e-14 5.59552404e-14 7.21644966e-14]

# %%
def least_squares(X, y):
    """Returns the least-squares solution of the equation
    
        (X^T X)β = X^T y
        
    :param X:
        A matrix of size N x M.
    :param y:
        A column vector of length N.
    """
    XT = np.transpose(X)
    return la.solve(XT @ X, XT @ y)

# %%
# data points
xi = [1, 2, 3,  4]
yi = [6, 5, 7, 10]

# define matrices, X and y
X = np.vstack([
    np.ones(len(xi)),
    xi
]).T
print(X)
Y = yi

# find least-squares solution
b1, b2 = least_squares(X, Y)
print(f"""
beta_1 = {b1}, beta_2 = {b2}
""")

# draw
plt.figure(figsize=[6, 4])
ax = plt.subplot()

plt.plot(xi, yi, "or", markeredgewidth=0.5, markeredgecolor="k",
         label="Data")

xs = np.linspace(0, 5, 100)
ys = b1 + b2*xs
plt.plot(xs, ys, "-b", label="Least-squares fit")

plt.xlim([0, 5])
plt.ylim([4, 10.5])
plt.grid()
plt.legend()
ax.set_xticks(range(6))
plt.xlabel("$x$")
plt.ylabel("$y$")

plt.show()
# Out:
# [[1. 1.]
#  [1. 2.]
#  [1. 3.]
#  [1. 4.]]
#
# beta_1 = 3.4999999999999987, beta_2 = 1.4000000000000004

# %%
c1, c2 = la.lstsq(X, Y, rcond=None)[0]
print(f"""Result from numpy.linalg.lstsq:

beta_1 = {c1}, beta_2 = {c2}
""")
# Out:
# Result from numpy.linalg.lstsq:
#
# beta_1 = 3.4999999999999996, beta_2 = 1.4000000000000001

# %%
xi, yi = map(np.array, zip(*[
    [2, 3],
    [4, 5],
    [5, 7]
]))
xi
# Out:
#   File "/var/folders/kk/2pj93ygs67nbx9_42r_c6_3c0000gn/T/ipykernel_52439/2893685796.py", line 5
#     ]))«
#        ^
# SyntaxError: invalid character '«' (U+00AB)

# %%
# data points
xi, yi = map(np.array, zip(*[
    [-2.46334563, -1.56845224],
    [ 2.63761337,  1.47389564],
    [ 0.32081604, -0.40868361],
    [ 1.58426449,  1.29565802],
    [ 0.42207065,  0.83838473],
    [ 1.51310164,  0.3286777 ],
    [ 0.8712766 , -0.08207119],
    [-0.2367237 ,  0.39619505],
    [-1.6625065 , -1.33260236],
    [ 2.45970384,  1.16775851],
    [ 0.20168962, -0.38754006],
    [ 0.48952169, -0.25543757],
    [-2.36931404, -1.63349134],
    [ 2.05834532,  1.509814  ],
    [-2.26005793, -0.95979945],
    [-2.61534704, -1.43735164],
    [ 0.78758072,  1.08449257],
    [-1.05029032, -0.1194829 ],
    [ 1.85306552,  1.47436698],
    [ 0.81894698,  1.0580295 ],
]))

# find least-squares solution
X = np.vstack([
    xi * xi,
    xi * yi,
    yi * yi,
]).T
Y = np.ones(len(X))

a, b, c = least_squares(X, Y)
print(f"""
a = {a}, b = {b}, c = {c}
""")

# draw
x = np.linspace(-3, 3, 201)
y = np.linspace(-2, 2, 181)
xx, yy = np.meshgrid(x, y)
zz = a*xx*xx + b*xx*yy + c*yy*yy

plt.figure()
plt.subplot().set_aspect("equal")
plt.contour(xx, yy, zz, [1.0], colors="r")
plt.plot(xi, yi, ".b", label="data")
plt.grid()
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.legend()
plt.show()
# Out:
# a = 1.0726812636427032, b = -3.274675186932553, c = 2.8910786182027257

# %%
w, v = la.eig([
    [a  , b/2],
    [b/2, c  ]
])
print("""
semi-minor = {}, semi-major = {}
""".format(*sorted(1/np.sqrt(w))))
# Out:
# semi-minor = 0.5093353051173539, semi-major = 3.028309546509392
